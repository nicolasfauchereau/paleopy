# %% [markdown]
# # illustrates the use of the `ensemble` and `composite` classes

# %%
# %matplotlib inline

# %%
import sys
from matplotlib import pyplot as plt

# %%
jsons = './jsons/proxies/'

# %%
sys.path.append('/Users/nicolasf/CODE/paleopy/')

# %%
from paleopy.core.ensemble import ensemble
from paleopy.core.analogs import analogs
from paleopy.plotting.scalar_plot import scalar_plot

# %%
ens = ensemble(jsons, season='DJF')

# %%
plt.hist(ens.analog_years)
# Out:
# (array([ 21.,  26.,  13.,  35.,   0.,  10.,  13.,  16.,  11.,  30.]),
#  array([ 1980. ,  1983.4,  1986.8,  1990.2,  1993.6,  1997. ,  2000.4,
#          2003.8,  2007.2,  2010.6,  2014. ]),
#  <a list of 10 Patch objects>)

# %%
ens.dict_proxies
# Out:
# {'Amedee': {'analog_years': [1983, 1987, 1997, 2001, 2003, 2013, 2014],
#   'calc_anoms': True,
#   'category': 'B',
#   'climatology': [1981, 2010],
#   'coords': [166.47, -22.48],
#   'dataset': 'ersst',
#   'detrend': True,
#   'distance_point': 71.98760982961697,
#   'extracted_coords': [166.0, -22.0],
#   'period': [1979, 2014],
#   'season': 'DJF',
#   'sitename': 'Amedee',
#   'trend_params': {'intercept': -16.257205985829472,
#    'pval': 0.17857648458483455,
#    'rval': 0.30471056443545524,
#    'slope': 0.00815872997636833,
#    'sterr': 0.007825350019529064},
#   'value': -0.26,
#   'variable': 'sst'},
#  'Avoca': {'analog_years': [1982, 1985, 1986, 1988, 1991, 1993, 2009],
#   'calc_anoms': True,
#   'category': 'B',
#   'climatology': [1981, 2010],
#   'coords': [171.405812, -43.043031],
#   'dataset': 'vcsn',
#   'detrend': True,
#   'distance_point': 0.9069296145614849,
#   'extracted_coords': [171.4, -43.05],
#   'period': [1979, 2014],
#   'season': 'DJF',
#   'sitename': 'Avoca',
#   'trend_params': {'intercept': -10.194280501596959,
#    'pval': 0.042091710019128016,
#    'rval': 0.8102678325744178,
#    'slope': 0.0049609562030229,
#    'sterr': 0.020498722188612303},
#   'value': -0.53,
#   'variable': 'TMean'},
#  'Browning Creek': {'analog_years': [1982, 1986, 1991, 2002, 2005, 2009, 2013],
#   'calc_anoms': True,
#   'category': 'B',
#   'climatology': [1981, 2010],
#   'coords': [169.836463, -43.850548],
#   'dataset': 'vcsn',
#   'detrend': True,
#   'distance_point': 1.0865382380225623,
#   'extracted_coords': [169.85, -43.85],
#   'period': [1979, 2014],
#   'season': 'DJF',
#   'sitename': 'Browning Creek',
#   'trend_params': {'intercept': -9.97375702134693,
#    'pval': 0.03704344164215627,
#    'rval': 0.8326802675848094,
#    'slope': 0.0048528760781283275,
#    'sterr': 0.02278939124519535},
#   'value': -0.62,
#   'variable': 'TMean'},
#  'Cameron': {'analog_years': [1982, 1985, 1988, 1991, 1992, 1993, 2009],
#   'calc_anoms': True,
#   'category': 'B',
#   'climatology': [1981, 2010],
#   'coords': [171.505139, -42.934067],
#   'dataset': 'vcsn',
#   'detrend': True,
#   'distance_point': 1.8192403316195496,
#   'extracted_coords': [171.5, -42.949999999999996],
#   'period': [1979, 2014],
#   'season': 'DJF',
#   'sitename': 'Cameron',
#   'trend_params': {'intercept': -14.038556300904384,
#    'pval': 0.0601424271587651,
#    'rval': 0.7314507634335753,
#    'slope': 0.006891841274886244,
#    'sterr': 0.019911797923399123},
#   'value': -0.81,
#   'variable': 'TMean'},
#  'Caples': {'analog_years': [1982, 1985, 1988, 1991, 1993, 2004, 2013],
#   'calc_anoms': True,
#   'category': 'B',
#   'climatology': [1981, 2010],
#   'coords': [168.182845, -44.801851],
#   'dataset': 'vcsn',
#   'detrend': True,
#   'distance_point': 1.368219270987994,
#   'extracted_coords': [168.2, -44.8],
#   'period': [1979, 2014],
#   'season': 'DJF',
#   'sitename': 'Caples',
#   'trend_params': {'intercept': -63.58789158841167,
#    'pval': 0.2818597690737743,
#    'rval': 0.1009225879975039,
#    'slope': 0.03175292085688571,
#    'sterr': 0.01881561882968615},
#   'value': -0.35,
#   'variable': 'TMean'},
#  'Cass': {'analog_years': [1985, 1987, 1988, 1991, 1992, 2002, 2009],
#   'calc_anoms': True,
#   'category': 'B',
#   'climatology': [1981, 2010],
#   'coords': [170.315493, -43.652675],
#   'dataset': 'vcsn',
#   'detrend': True,
#   'distance_point': 1.2806903178437616,
#   'extracted_coords': [170.29999999999998, -43.65],
#   'period': [1979, 2014],
#   'season': 'DJF',
#   'sitename': 'Cass',
#   'trend_params': {'intercept': -33.89554362085976,
#    'pval': 0.1722960851041155,
#    'rval': 0.3223081965703938,
#    'slope': 0.016893347068156254,
#    'sterr': 0.01681277833304685},
#   'value': -0.16,
#   'variable': 'TMean'},
#  'Clarke': {'analog_years': [1985, 1993, 2002, 2003, 2004, 2005, 2012],
#   'calc_anoms': True,
#   'category': 'B',
#   'climatology': [1981, 2010],
#   'coords': [169.451667, -43.873611],
#   'dataset': 'vcsn',
#   'detrend': True,
#   'distance_point': 2.627172436011875,
#   'extracted_coords': [169.45, -43.85],
#   'period': [1979, 2014],
#   'season': 'DJF',
#   'sitename': 'Clarke',
#   'trend_params': {'intercept': -0.4961696901603999,
#    'pval': 0.0020971748912606285,
#    'rval': 0.9904603551790956,
#    'slope': 0.00018317245326029133,
#    'sterr': 0.015204340521103176},
#   'value': -0.13,
#   'variable': 'TMean'},
#  'Crow': {'analog_years': [1980, 1983, 1984, 1993, 2011, 2012, 2014],
#   'calc_anoms': True,
#   'category': 'WB',
#   'climatology': [1981, 2010],
#   'coords': [170.998122, -43.346222],
#   'dataset': 'vcsn',
#   'detrend': True,
#   'distance_point': 0.44641812756074506,
#   'extracted_coords': [171.0, -43.35],
#   'period': [1979, 2014],
#   'season': 'DJF',
#   'sitename': 'Crow',
#   'trend_params': {'intercept': -19.30790938900566,
#    'pval': 0.08826696671040954,
#    'rval': 0.6141097765306048,
#    'slope': 0.009555664868839527,
#    'sterr': 0.01877185998244574},
#   'value': -0.62,
#   'variable': 'TMean'},
#  'Falls Creek': {'analog_years': [1982, 1985, 1991, 1992, 1993, 2003, 2013],
#   'calc_anoms': True,
#   'category': 'B',
#   'climatology': [1981, 2010],
#   'coords': [168.015937, -44.824221],
#   'dataset': 'vcsn',
#   'detrend': True,
#   'distance_point': 2.9703551841622544,
#   'extracted_coords': [168.0, -44.8],
#   'period': [1979, 2014],
#   'season': 'DJF',
#   'sitename': 'Falls Creek',
#   'trend_params': {'intercept': -65.75229220312369,
#    'pval': 0.2823820849116013,
#    'rval': 0.10026563356905305,
#    'slope': 0.03283566429908928,
#    'sterr': 0.019418114328752147},
#   'value': -0.71,
#   'variable': 'TMean'},
#  'Frances': {'analog_years': [1982, 1987, 1988, 1991, 1993, 2012, 2013],
#   'calc_anoms': True,
#   'category': 'B',
#   'climatology': [1981, 2010],
#   'coords': [168.395713, -44.596521],
#   'dataset': 'vcsn',
#   'detrend': True,
#   'distance_point': 0.5143242470101659,
#   'extracted_coords': [168.4, -44.6],
#   'period': [1979, 2014],
#   'season': 'DJF',
#   'sitename': 'Frances',
#   'trend_params': {'intercept': -65.9994167247913,
#    'pval': 0.25416488554783195,
#    'rval': 0.14065133750220382,
#    'slope': 0.03294037822767213,
#    'sterr': 0.021820002370902487},
#   'value': -0.41,
#   'variable': 'TMean'},
#  'Fraser': {'analog_years': [1982, 1985, 1988, 1991, 1993, 2004, 2013],
#   'calc_anoms': True,
#   'category': 'B',
#   'climatology': [1981, 2010],
#   'coords': [168.186884, -44.786354],
#   'dataset': 'vcsn',
#   'detrend': True,
#   'distance_point': 1.8355804164909812,
#   'extracted_coords': [168.2, -44.8],
#   'period': [1979, 2014],
#   'season': 'DJF',
#   'sitename': 'Fraser',
#   'trend_params': {'intercept': -63.58789158841167,
#    'pval': 0.2818597690737743,
#    'rval': 0.1009225879975039,
#    'slope': 0.03175292085688571,
#    'sterr': 0.01881561882968615},
#   'value': -0.21,
#   'variable': 'TMean'},
#  'Greenlaw': {'analog_years': [1985, 1991, 1992, 2000, 2003, 2007, 2011],
#   'calc_anoms': True,
#   'category': 'B',
#   'climatology': [1981, 2010],
#   'coords': [171.419497, -43.006108],
#   'dataset': 'vcsn',
#   'detrend': True,
#   'distance_point': 1.7237375830879502,
#   'extracted_coords': [171.4, -43.0],
#   'period': [1979, 2014],
#   'season': 'DJF',
#   'sitename': 'Greenlaw',
#   'trend_params': {'intercept': -0.938794534869803,
#    'pval': 0.004010844782972325,
#    'rval': 0.9817565410202842,
#    'slope': 0.00036856270131330996,
#    'sterr': 0.015996135111600276},
#   'value': -0.26,
#   'variable': 'TMean'},
#  'Gunn': {'analog_years': [1985, 1988, 1992, 1993, 2003, 2012, 2013],
#   'calc_anoms': True,
#   'category': 'B',
#   'climatology': [1981, 2010],
#   'coords': [170.327343, -43.368294],
#   'dataset': 'vcsn',
#   'detrend': True,
#   'distance_point': 2.735649736102959,
#   'extracted_coords': [170.35, -43.35],
#   'period': [1979, 2014],
#   'season': 'DJF',
#   'sitename': 'Gunn',
#   'trend_params': {'intercept': -44.62551590658575,
#    'pval': 0.239065781709261,
#    'rval': 0.16662847655017715,
#    'slope': 0.02228634520178144,
#    'sterr': 0.01575742336431141},
#   'value': -0.59,
#   'variable': 'TMean'},
#  'Hopkins': {'analog_years': [1982, 1985, 1986, 1991, 1993, 2005, 2009],
#   'calc_anoms': True,
#   'category': 'B',
#   'climatology': [1981, 2010],
#   'coords': [169.887499, -43.942569],
#   'dataset': 'vcsn',
#   'detrend': True,
#   'distance_point': 1.2970287700020637,
#   'extracted_coords': [169.9, -43.949999999999996],
#   'period': [1979, 2014],
#   'season': 'DJF',
#   'sitename': 'Hopkins',
#   'trend_params': {'intercept': -6.169246486693413,
#    'pval': 0.02461192008098945,
#    'rval': 0.8883920405824485,
#    'slope': 0.002964945340390939,
#    'sterr': 0.020964410224498253},
#   'value': -0.39,
#   'variable': 'TMean'},
#  'Hunter': {'analog_years': [1982, 1985, 1986, 1991, 2002, 2005, 2013],
#   'calc_anoms': True,
#   'category': 'B',
#   'climatology': [1981, 2010],
#   'coords': [169.636111, -44.120833],
#   'dataset': 'vcsn',
#   'detrend': True,
#   'distance_point': 2.5666308092028607,
#   'extracted_coords': [169.65, -44.1],
#   'period': [1979, 2014],
#   'season': 'DJF',
#   'sitename': 'Hunter',
#   'trend_params': {'intercept': -13.78221825177966,
#    'pval': 0.048192970118530354,
#    'rval': 0.7833787804635772,
#    'slope': 0.006753518611745721,
#    'sterr': 0.0243660153771852},
#   'value': -0.14,
#   'variable': 'TMean'},
#  'Jollie': {'analog_years': [1980, 1983, 1984, 1993, 2011, 2012, 2014],
#   'calc_anoms': True,
#   'category': 'WB',
#   'climatology': [1981, 2010],
#   'coords': [170.33, -43.697778],
#   'dataset': 'vcsn',
#   'detrend': True,
#   'distance_point': 1.6256872192126688,
#   'extracted_coords': [170.35, -43.699999999999996],
#   'period': [1979, 2014],
#   'season': 'DJF',
#   'sitename': 'Jollie',
#   'trend_params': {'intercept': -34.3212684109616,
#    'pval': 0.1794139117633087,
#    'rval': 0.30241098016564527,
#    'slope': 0.017112082504488944,
#    'sterr': 0.016333715182849592},
#   'value': -0.99,
#   'variable': 'TMean'},
#  'Mistake': {'analog_years': [1980, 1983, 1984, 2009, 2011, 2012, 2014],
#   'calc_anoms': True,
#   'category': 'WB',
#   'climatology': [1981, 2010],
#   'coords': [168.015261, -44.843612],
#   'dataset': 'vcsn',
#   'detrend': True,
#   'distance_point': 1.3962830031489613,
#   'extracted_coords': [168.0, -44.85],
#   'period': [1979, 2014],
#   'season': 'DJF',
#   'sitename': 'Mistake',
#   'trend_params': {'intercept': -65.8475412573255,
#    'pval': 0.28106717291198585,
#    'rval': 0.10192573306343916,
#    'slope': 0.03288033270408617,
#    'sterr': 0.019543359300543545},
#   'value': -1.14,
#   'variable': 'TMean'},
#  'Oroko': {'analog_years': [1984, 1988, 1998, 2004, 2006, 2009, 2014],
#   'calc_anoms': True,
#   'category': 'B',
#   'climatology': [1981, 2010],
#   'coords': [170.307329, -43.222615],
#   'dataset': 'vcsn',
#   'detrend': True,
#   'distance_point': 2.5822452692301705,
#   'extracted_coords': [170.29999999999998, -43.199999999999996],
#   'period': [1979, 2014],
#   'season': 'DJF',
#   'sitename': 'Oroko',
#   'trend_params': {'intercept': -29.90780231465947,
#    'pval': 0.2024754863969238,
#    'rval': 0.2434169125900519,
#    'slope': 0.014987808990856173,
#    'sterr': 0.01261882347609148},
#   'value': -0.42,
#   'variable': 'TMean'},
#  'Pear Drop': {'analog_years': [1982, 1986, 1991, 1993, 2004, 2012, 2013],
#   'calc_anoms': True,
#   'category': 'B',
#   'climatology': [1981, 2010],
#   'coords': [168.849048, -44.251904],
#   'dataset': 'vcsn',
#   'detrend': True,
#   'distance_point': 0.2247425428501868,
#   'extracted_coords': [168.85, -44.25],
#   'period': [1979, 2014],
#   'season': 'DJF',
#   'sitename': 'Pear Drop',
#   'trend_params': {'intercept': -41.424550060291764,
#    'pval': 0.16442077022798401,
#    'rval': 0.3452490872351799,
#    'slope': 0.020637071662183943,
#    'sterr': 0.02155178340676052},
#   'value': -0.69,
#   'variable': 'TMean'},
#  'Pyke': {'analog_years': [1987, 1992, 1997, 2001, 2003, 2005, 2010],
#   'calc_anoms': True,
#   'category': 'N',
#   'climatology': [1981, 2010],
#   'coords': [168.178333, -44.803611],
#   'dataset': 'vcsn',
#   'detrend': True,
#   'distance_point': 1.7549068403191712,
#   'extracted_coords': [168.2, -44.8],
#   'period': [1979, 2014],
#   'season': 'DJF',
#   'sitename': 'Pyke',
#   'trend_params': {'intercept': -63.58789158841167,
#    'pval': 0.2818597690737743,
#    'rval': 0.1009225879975039,
#    'slope': 0.03175292085688571,
#    'sterr': 0.01881561882968615},
#   'value': -0.1,
#   'variable': 'TMean'},
#  'Rarotonga': {'analog_years': [1982, 1997, 1999, 2000, 2001, 2006, 2009],
#   'calc_anoms': True,
#   'category': 'WA',
#   'climatology': [1981, 2010],
#   'coords': [200.18, -21.23],
#   'dataset': 'ersst',
#   'detrend': True,
#   'distance_point': 87.56368858840081,
#   'extracted_coords': [200.0, -22.0],
#   'period': [1979, 2014],
#   'season': 'DJF',
#   'sitename': 'Rarotonga',
#   'trend_params': {'intercept': -60.96501637775517,
#    'pval': 0.5594795521984811,
#    'rval': 0.0004755169130383159,
#    'slope': 0.03053594702988668,
#    'sterr': 0.00787486438427222},
#   'value': 0.6,
#   'variable': 'sst'},
#  'Taramakau': {'analog_years': [1980, 1983, 1984, 1993, 2012, 2013, 2014],
#   'calc_anoms': True,
#   'category': 'WB',
#   'climatology': [1981, 2010],
#   'coords': [171.486667, -42.899444],
#   'dataset': 'vcsn',
#   'detrend': True,
#   'distance_point': 1.0871204462090915,
#   'extracted_coords': [171.5, -42.9],
#   'period': [1979, 2014],
#   'season': 'DJF',
#   'sitename': 'Taramakau',
#   'trend_params': {'intercept': -4.631371425840538,
#    'pval': 0.025907188825487835,
#    'rval': 0.8825579929069363,
#    'slope': 0.002232142578944394,
#    'sterr': 0.014993356834044997},
#   'value': -0.69,
#   'variable': 'TMean'},
#  'Temple': {'analog_years': [1985, 1986, 1991, 1993, 2004, 2005, 2012],
#   'calc_anoms': True,
#   'category': 'B',
#   'climatology': [1981, 2010],
#   'coords': [169.709872, -44.146466],
#   'dataset': 'vcsn',
#   'detrend': True,
#   'distance_point': 0.8796866025775316,
#   'extracted_coords': [169.7, -44.15],
#   'period': [1979, 2014],
#   'season': 'DJF',
#   'sitename': 'Temple',
#   'trend_params': {'intercept': -3.6311347811284476,
#    'pval': 0.015298874259852102,
#    'rval': 0.9304908575777648,
#    'slope': 0.0017132203270632579,
#    'sterr': 0.01949153055147508},
#   'value': -0.79,
#   'variable': 'TMean'},
#  'Turnbull': {'analog_years': [1982, 1985, 1986, 1991, 1993, 2005, 2009],
#   'calc_anoms': True,
#   'category': 'B',
#   'climatology': [1981, 2010],
#   'coords': [169.850303, -43.877607],
#   'dataset': 'vcsn',
#   'detrend': True,
#   'distance_point': 2.488542980472772,
#   'extracted_coords': [169.85, -43.9],
#   'period': [1979, 2014],
#   'season': 'DJF',
#   'sitename': 'Turnbull',
#   'trend_params': {'intercept': -3.963015413988626,
#    'pval': 0.016063907506014153,
#    'rval': 0.9270240329615558,
#    'slope': 0.0018654834941018896,
#    'sterr': 0.020212833754543347},
#   'value': -0.4,
#   'variable': 'TMean'},
#  'Washington Isl.': {'analog_years': [1984,
#    1989,
#    1997,
#    1999,
#    2000,
#    2008,
#    2011],
#   'calc_anoms': True,
#   'category': 'WB',
#   'climatology': [1981, 2010],
#   'coords': [199.612518, 4.686322],
#   'dataset': 'gpcp',
#   'detrend': True,
#   'distance_point': 141.2904361997061,
#   'extracted_coords': [198.75, 3.75],
#   'period': [1979, 2014],
#   'season': 'DJF',
#   'sitename': 'Washington Isl.',
#   'trend_params': {'intercept': 37.98929683664041,
#    'pval': -0.05281012092964275,
#    'rval': 0.7631913877572739,
#    'slope': -0.019223837085576054,
#    'sterr': 0.0632789836981765},
#   'value': 'WB',
#   'variable': 'Rain'}}

# %%
sst = analogs(ens, 'ersst', 'sst').composite()

# %%
f = scalar_plot(sst, test=0.1).plot()

# %%
sst.close()

# %%
hgt = analogs(ens, 'ncep', 'hgt_1000').composite()

# %%
f = scalar_plot(hgt, test=0.1, proj='spstere', grid=False).plot()
